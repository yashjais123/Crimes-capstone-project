# %% [markdown]
# # Crimes in India - Capstone Project

# %% [markdown]
# # Unsupervised ML (Clustering)

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# # Note: This phase requires your general knowledge and thought process to merge the right datasets and the right columns. Collecting quality data is a key factor to create meaningful clusters and Analysis.

# %% [markdown]
# # Create 3 clusters as below.
#
# # 1) Sensitive Area's
#
# # 2) Moderate Area's
#
# # 3) Peaceful Area's"

# %% [markdown]
# # Example -
#
# # 1) What is impacting more crimes in sensitive areas.
#
# # 2) What needs to be done to reduce crime.
#
# # 3) Most safe and unsafe districts.
#
# # Etc.......Anything that you observe (If you want, you can plot various graphs to analyze)"

# %% [markdown]
# # Import necerrssary liabires

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"D:\b.com final year\BCom3  2016-2017\01_District_wise_crimes_committed_IPC_2001_2012.csv")

# %%
data
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
# Lets check the shape of dataset
data.shape
# Out:
# (9017, 33)

# %% [markdown]
# So , here we have 9840 rows and 33 columns

# %% [markdown]
# # Data is Duplicated ?

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# so, here we have 0 Duplicated Data

# %%
#Lets check the data type of dataset
data.dtypes
# Out:
# STATE/UT                                               object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT TO MURDER                                       int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               int64
# RAPE                                                    int64
# CUSTODIAL RAPE                                          int64
# OTHER RAPE                                              int64
# KIDNAPPING & ABDUCTION                                  int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             int64
# KIDNAPPING AND ABDUCTION OF OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION AND ASSEMBLY FOR DACOITY                    int64
# ROBBERY                                                 int64
# ...

# %% [markdown]
# so here we have
#
# Object type - STATE/UT and DISTRICT columns are object columns
#
# int64 type - Then All columns are int64

# %% [markdown]
# # Data Describe

# %%
data.describe()
# Out:
#               YEAR      MURDER  ATTEMPT TO MURDER  \
# count  9017.000000  9017.00000        9017.000000
# mean   2006.629034    89.28535          78.069646
# std       3.463623   327.27503         303.446020
# min    2001.000000     0.00000           0.000000
# 25%    2004.000000    18.00000          10.000000
# 50%    2007.000000    38.00000          28.000000
# 75%    2010.000000    66.00000          56.000000
# max    2012.000000  7601.00000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9017.000000  9017.000000     9017.000000
# mean                                    9.895531    53.041366        0.005767
# std                                    59.521657   190.741450        0.115223
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
data = data[['STATE/UT', 'DISTRICT', 'YEAR',  'TOTAL IPC CRIMES']]
data = data.fillna(0)

# %%
data.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'TOTAL IPC CRIMES'], dtype='object')

# %% [markdown]
# We will use the MinMaxScaler from the sklearn library to scale the data between 0 and 1.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data.iloc[:,3:])

# %% [markdown]
# We will use the KMeans algorithm from the sklearn library to perform clustering on the normalized data. We will set the number of clusters to 3.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, init='k-means++')
kmeans.fit(data_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
data['cluster'] = kmeans.labels_

# %%
peaceful_Areas = data[data['cluster'] == 0]
sensitive_Areas = data[data['cluster'] == 1]
moderate_Areas = data[data['cluster'] == 2]

# %%
peaceful_Areas
# Out:
#             STATE/UT       DISTRICT  YEAR  TOTAL IPC CRIMES  cluster
# 0     ANDHRA PRADESH       ADILABAD  2001              4154        0
# 1     ANDHRA PRADESH      ANANTAPUR  2001              4125        0
# 2     ANDHRA PRADESH       CHITTOOR  2001              5818        0
# 3     ANDHRA PRADESH       CUDDAPAH  2001              3140        0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001              6507        0
# ...              ...            ...   ...               ...      ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012                60        0
# 9013     LAKSHADWEEP          TOTAL  2012                60        0
# 9014      PUDUCHERRY       KARAIKAL  2012               787        0
# 9015      PUDUCHERRY     PUDUCHERRY  2012              3494        0
# 9016      PUDUCHERRY          TOTAL  2012              4281        0
#
# [8772 rows x 5 columns]

# %%
sensitive_Areas
# Out:
#             STATE/UT DISTRICT  YEAR  TOTAL IPC CRIMES  cluster
# 28    ANDHRA PRADESH    TOTAL  2001            130089        1
# 169          GUJARAT    TOTAL  2001            103419        1
# 285        KARNATAKA    TOTAL  2001            109098        1
# 302           KERALA    TOTAL  2001            103847        1
# 351   MADHYA PRADESH    TOTAL  2001            181741        1
# ...              ...      ...   ...               ...      ...
# 8657     MAHARASHTRA    TOTAL  2012            202700        1
# 8806       RAJASTHAN    TOTAL  2012            170948        1
# 8851      TAMIL NADU    TOTAL  2012            200474        1
# 8938   UTTAR PRADESH    TOTAL  2012            198093        1
# 8982     WEST BENGAL    TOTAL  2012            161427        1
#
# [119 rows x 5 columns]

# %%
moderate_Areas
# Out:
#           STATE/UT        DISTRICT  YEAR  TOTAL IPC CRIMES  cluster
# 70           ASSAM           TOTAL  2001             36877        2
# 115          BIHAR           TOTAL  2001             88432        2
# 135   CHHATTISGARH           TOTAL  2001             38460        2
# 190        HARYANA           TOTAL  2001             38759        2
# 253      JHARKHAND           TOTAL  2001             25447        2
# ...            ...             ...   ...               ...      ...
# 8630   MAHARASHTRA   MUMBAI COMMR.  2012             30508        2
# 8734        ODISHA           TOTAL  2012             67957        2
# 8763        PUNJAB           TOTAL  2012             35790        2
# 8971   WEST BENGAL         KOLKATA  2012             25370        2
# 8997      DELHI UT  DELHI UT TOTAL  2012             54287        2
#
# [126 rows x 5 columns]

# %% [markdown]
# Crimes in India :-
#
#     The sensitive areas cluster has a high incidence of crimes against women, including rape, kidnapping, and dowry deaths. This suggests that there is a need for greater attention towards women's safety and empowerment in these areas.

# %% [markdown]
#     To reduce crime, there needs to be better enforcement of laws, greater public awareness, and investment in social and economic development. In sensitive areas, there is a particular need for targeted interventions to address crimes against women.What needs to be done to reduce crime?

# %% [markdown]
#     Most safe and unsafe districts The most unsafe districts are likely to be found in the sensitive areas cluster. The most safe districts are likely to be found in the peaceful areas cluster. However, it is important to note that crime rates

# %% [markdown]
#     To Some causes of crimes are region specific Insurgents committed Left wing extremists committed  mostly in Chhattisgarh. mostly in Jammu & Kashmir

# %% [markdown]
#     There’s a rapid increase in the crime rate in our Indian economy. These crimes are caused due to the unpunished offenders . The problem of crime  has been a relentless menace to society
